# %% [markdown]
# <a href="https://colab.research.google.com/github/henriquebap/Machine_Learning_HB/blob/main/CNN_Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as bibliotecas OpenCV, DLib e im_show
import cv2
import dlib
from google.colab.patches import cv2_imshow

# %%
imagem = cv2.imread('/content/people2.jpg')
imagem2 = cv2.imread('/content/spain.jpg')
imagem3 = cv2.imread('/content/tlou_cast.jpg')

# %%
detector_face_cnn = dlib.cnn_face_detection_model_v1('/content/mmod_human_face_detector.dat')

# %%
deteccoes = detector_face_cnn(imagem2, 1)
for face in deteccoes:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(l,t,r,b,c)
  cv2.rectangle(imagem2,(l,t), (r,b), (255, 0, 0), 2)
cv2_imshow(imagem2)
# Out:
# 445 286 502 343 1.1072708368301392
# 1004 85 1052 132 1.0968245267868042
# 1033 330 1080 377 1.0907491445541382
# 635 80 682 128 1.081192135810852
# 238 332 295 389 1.0768026113510132
# 647 297 704 354 1.0711971521377563
# 811 55 879 123 1.0706678628921509
# 299 104 346 152 1.0684953927993774
# 894 359 962 427 1.05705726146698
# 467 109 514 156 1.0502296686172485
# 117 107 174 164 1.0450828075408936
# 1015 310 1097 391 0.8183664083480835
# <PIL.Image.Image image mode=RGB size=1296x729>
