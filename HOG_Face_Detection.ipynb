# %% [markdown]
# <a href="https://colab.research.google.com/github/henriquebap/Machine_Learning_HB/blob/main/HOG_Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Histogram Of Oriented Gradients (HOG)
# https://learnopencv.com/histogram-of-oriented-gradients/

# %%
# Importando as bibliotecas OpenCV, DLib e im_show
import cv2
import dlib
from google.colab.patches import cv2_imshow

# %%
# Insira aqui o seu arquivo
imagem = cv2.imread('people2.jpg')

# %%
detector_face_hog = dlib.get_frontal_face_detector()

# %%
deteccoes = detector_face_hog(imagem, 2) # O segundo parâmetro é semelhante ao Scale Factor do Opencv (Haarcascades)

# %%
deteccoes
# Out:
# rectangles[[(428, 39) (466, 77)], [(665, 89) (702, 126)], [(713, 102) (758, 147)], [(828, 97) (873, 142)], [(908, 67) (952, 112)], [(777, 60) (814, 97)], [(97, 89) (134, 126)], [(602, 68) (640, 106)], [(385, 57) (430, 102)], [(482, 77) (520, 114)], [(171, 42) (216, 87)], [(236, 52) (280, 97)], [(325, 56) (362, 93)], [(549, 68) (586, 106)]]

# %%
len(deteccoes)
# Out:
# 14

# %%
for face in deteccoes:
  print(face.left())
  print(face.top())
  print(face.right())
  print(face.bottom())
# Out:
# 428
# 39
# 466
# 77
# 665
# 89
# 702
# 126
# 713
# 102
# 758
# 147
# 828
# 97
# 873
# 142
# 908
# 67
# 952
# 112
# 777
# 60
# 814
# 97
# 97
# 89
# 134
# 126
# 602
# 68
# 640
# 106
# 385
# 57
# 430
# 102
# 482
# 77
# 520
# 114
# 171
# 42
# 216
# 87
# 236
# 52
# 280
# 97
# 325
# 56
# 362
# 93
# 549
# 68
# 586
# 106

# %%
for face in deteccoes:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(imagem, (l, t), (r, b), (0, 255, 0), 1)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537>

# %%
imagem = cv2.imread('/content/spain.jpg')
detector_face_hog = dlib.get_frontal_face_detector()
deteccoes = detector_face_hog(imagem, 2)
for face in deteccoes:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(imagem, (l, t), (r, b), (0, 255, 0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1296x729>
