# %%
import pandas as pd

# %%
df = pd.read_csv('/content/household_power_consumption.txt', sep=';', low_memory=False)

# %%
df.shape
# Out:
# (97195, 9)

# %%
# Salva um novo dataframe somente com as colunas desejadas.
df1 = df.loc[:, ['Global_active_power', 'Sub_metering_2']]
df1.head()
# Out:
#   Global_active_power Sub_metering_2
# 0               4.216          1.000
# 1               5.360          1.000
# 2               5.374          2.000
# 3               5.388          1.000
# 4               3.666          1.000

# %%
# Nota-se que são duas colunas que aparentam ser do tipo 'float', mas são 'object' (strings)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97195 entries, 0 to 97194
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Global_active_power  97194 non-null  object
#  1   Sub_metering_2       97194 non-null  object
# dtypes: object(2)
# memory usage: 1.5+ MB

# %%
# Se tentarmos converter em float64, encontraremos um erro...
df1 = df1.astype('float64')
df1

# %%
# Vamos identificar os registros com o caractere "?" informado no erro acima....
df1[df1['Global_active_power'] == '?'].index
# Out:
# Int64Index([6839, 6840, 19724, 19725, 41832, 61909], dtype='int64')

# %%
# Em seguida, excluímos tais registros...
df1 = df1.drop(df[df['Global_active_power'] == '?'].index)
df1
# Out:
#       Global_active_power Sub_metering_2
# 0                   4.216          1.000
# 1                   5.360          1.000
# 2                   5.374          2.000
# 3                   5.388          1.000
# 4                   3.666          1.000
# ...                   ...            ...
# 97190               2.388          0.000
# 97191               2.356          0.000
# 97192               2.364          0.000
# 97193               2.362          0.000
# 97194                 NaN            NaN
#
# [97189 rows x 2 columns]

# %%
# Agora podemos converter em float64
df1 = df1.astype('float64')
df1
# Out:
#        Global_active_power  Sub_metering_2
# 0                    4.216             1.0
# 1                    5.360             1.0
# 2                    5.374             2.0
# 3                    5.388             1.0
# 4                    3.666             1.0
# ...                    ...             ...
# 97190                2.388             0.0
# 97191                2.356             0.0
# 97192                2.364             0.0
# 97193                2.362             0.0
# 97194                  NaN             NaN
#
# [97189 rows x 2 columns]

# %%
# Agora, os registros estão no formato que desejamos :)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97189 entries, 0 to 97194
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Global_active_power  97188 non-null  float64
#  1   Sub_metering_2       97188 non-null  float64
# dtypes: float64(2)
# memory usage: 2.2 MB

# %%
df2 = df1.sample(20000, random_state = 10)
